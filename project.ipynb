# %% [markdown]
# Predict the number of tickets that will be sold for buses into Nairobi from cities in "up country" Kenya.

# %%
#import packages & data
import pandas as pd

df = pd.read_csv("C:\\Users\\18005\\OneDrive\\Documents\\GitHub\\Project3-Traffic-Jam\\project\\train_revised.csv")

# %%
#Drop irrelevant columns
df = df.drop(columns=["seat_number", "ride_id", "payment_receipt", "travel_date", "max_capacity","payment_method"])

# %%
#Filtering 
df = df[(df.travel_to == 'Nairobi') & (df.car_type == 'Bus')]
df = df.drop(columns = ["travel_to","car_type"])

# %%
#Groupby places
place = df.groupby("travel_from").nunique()

# %%
df = df.drop_duplicates()

# %%
#Sort by time
place.sort_values(by = "travel_time", ascending = False)
# Out:
#              travel_time
# travel_from
# Kisii                 25
# Rongo                 17
# Keroka                17
# Kijauri               12
# Nyachenge             11
# Awendo                 8
# Migori                 8
# Rodi                   6
# Homa Bay               4
# Sirare                 3
# Keumbu                 3
# Mbita                  2
# Ndhiwa                 2
# Kehancha               2
# Sori                   2
# Oyugis                 1
# Kendu Bay              1

# %%
#Group by time
df.groupby("travel_time").describe()
# Out:
#             travel_from
#                   count unique      top freq
# travel_time
# 19:03                 3      3  Kijauri    1
# 19:04                 3      3  Kijauri    1
# 19:05                 3      3  Kijauri    1
# 19:06                 3      3  Kijauri    1
# 19:07                 5      5   Migori    1
# 23:09                 3      3    Mbita    1
# 23:10                 4      4     Sori    1
# 5:00                  1      1    Kisii    1
# 5:10                  1      1    Kisii    1
# 6:59                  5      5   Migori    1
# 7:00                  6      6   Migori    1
# 7:01                  2      2   Keroka    1
# 7:02                  5      5  Kijauri    1
# 7:03                  5      5    Mbita    1
# 7:04                  7      7     Rodi    1
# 7:05                  7      7    Kisii    1
# 7:06                  3      3  Kijauri    1
# 7:07                  4      4  Kijauri    1
# 7:08                  8      8   Migori    1
# ...

# %%
#Sort by place
df.sort_values(by = "travel_from", ascending = False)
# Out:
#       travel_time travel_from
# 47716       23:10        Sori
# 21641        7:05        Sori
# 13266        7:00      Sirare
# 17874       19:07      Sirare
# 34613        6:59      Sirare
# ...           ...         ...
# 16171        7:00      Awendo
# 13420        7:15      Awendo
# 2152         7:08      Awendo
# 14305        7:12      Awendo
# 42453        8:00      Awendo
#
# [124 rows x 2 columns]

# %%
pd.crosstab(df.travel_time, df.travel_from)
# Out:
# travel_from  Awendo  Homa Bay  Kehancha  Kendu Bay  Keroka  Keumbu  Kijauri  \
# travel_time
# 19:03             0         0         0          0       6       0        9
# 19:04             0         0         0          0       4       0        3
# 19:05             0         0         0          0       5       0        3
# 19:06             0         0         0          0       3       0        7
# 19:07             2         0         0          0       0       0        0
# 23:09             0         0         0          0       0       0        0
# 23:10             0         0         0          0       0       0        0
# 5:00              0         0         0          0       0       0        0
# 5:10              0         0         0          0       0       0        0
# 6:59             28         0         0          0       0       0        0
# 7:00             10         0         0          0      10       0        0
# ...
